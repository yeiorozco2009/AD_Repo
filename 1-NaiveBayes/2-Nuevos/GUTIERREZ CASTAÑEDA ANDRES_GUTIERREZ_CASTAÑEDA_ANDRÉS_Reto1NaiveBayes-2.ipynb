# %% [markdown]
# ##1.IMPORTAR DATOS

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
solicitantes = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/0. SolicitantesCrédito-clase.xlsx')

# %%
solicitantes
# Out:
#       Unnamed: 0  Edad    Sexo Estado civil  Hijos  Perscargo  Estrato  \
# 0              1    38      NR       Casado      1          0        3
# 1              2    51      NR     Separado      6          1        4
# 2              3    37   Mujer       Casado      2          0        3
# 3              4    29      NR     Separado      1          0        2
# 4              5    42   Mujer       Casado      3          4        2
# ...          ...   ...     ...          ...    ...        ...      ...
# 8373        8374    31  Hombre      Soltero      2          0        5
# 8374        8375    38  Hombre     Separado      0          0        3
# 8375        8376    43   Mujer       Casado      1          2        2
# 8376        8377    37   Mujer       Casado      1          2        3
# 8377        8378    24      NR      Soltero      0          0        2
#
#      Nivel de estudios  Tipo de contrato  Ingresos  ...  Plazo    Cuota (COP)  \
# ...

# %% [markdown]
# ##2.LIMPIAMOS LOS DATOS

# %%
solicitantes.shape
# Out:
# (8378, 35)

# %%
## Elimino los registros donde PreApr esta vacio
XD = solicitantes.dropna(subset=['PreApr'])

# %%
## Escojo solo las variables que voy a usar como independientes.
XD = XD[['Edad','Hijos','Perscargo','Estrato','Ingresos','Egresos','Monto (EAD)','Plazo','Cuota (COP)']]

# %%
XD
# Out:
#       Edad  Hijos  Perscargo  Estrato  Ingresos  Egresos   Monto (EAD)  Plazo  \
# 0       38      1          0        3   5424576  7585302  2.815030e+06     48
# 1       51      6          1        4   1144064  1640079  6.301439e+05     36
# 2       37      2          0        3   2069853  2831440  1.280540e+06     36
# 3       29      1          0        2   1893080  2482276  1.393414e+06     24
# 4       42      3          4        2   3000367  3630221  2.252986e+06     24
# ...    ...    ...        ...      ...       ...      ...           ...    ...
# 8371    48      0          0        3   4831392  3392105  3.366188e+06     36
# 8373    31      2          0        5   5891088  4292158  3.918572e+06     48
# 8374    38      0          0        3   3092079  3028098  2.677266e+06     36
# 8375    43      1          2        2   2542007  3513112  1.375112e+06     36
# 8376    37      1          2        3   5677067  5264273  4.525366e+06     36
#
#         Cuota (COP)
# ...

# %%
## Escojo la variable dependiente.
yd = solicitantes['PreApr'].dropna()

# %%
yd
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 8371    1.0
# 8373    1.0
# 8374    1.0
# 8375    1.0
# 8376    1.0
# Name: PreApr, Length: 5842, dtype: float64

# %% [markdown]
# ## 3.Implementamos el modelo de Naive Bayes

# %%
### importamos las librerias necesarias.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.naive_bayes import GaussianNB

# %%
# convierto los datasets a arrays
XDArray = np.array(XD)
YdArray = np.array(yd)

# %%
XDArray
# Out:
# array([[3.80000000e+01, 1.00000000e+00, 0.00000000e+00, ...,
#         2.81503004e+06, 4.80000000e+01, 8.26915062e+04],
#        [5.10000000e+01, 6.00000000e+00, 1.00000000e+00, ...,
#         6.30143930e+05, 3.60000000e+01, 2.27812126e+04],
#        [3.70000000e+01, 2.00000000e+00, 0.00000000e+00, ...,
#         1.28054021e+06, 3.60000000e+01, 4.62945962e+04],
#        ...,
#        [3.80000000e+01, 0.00000000e+00, 0.00000000e+00, ...,
#         2.67726552e+06, 3.60000000e+01, 9.67895621e+04],
#        [4.30000000e+01, 1.00000000e+00, 2.00000000e+00, ...,
#         1.37511242e+06, 3.60000000e+01, 4.97136082e+04],
#        [3.70000000e+01, 1.00000000e+00, 2.00000000e+00, ...,
#         4.52536592e+06, 3.60000000e+01, 1.63602819e+05]])

# %%
### ENTRENAMOS EL MODELO (FASE TRAIN)
modeloNB = GaussianNB()  ##Variable que arroja el modelo.
modeloNB.fit(XDArray, YdArray)
# Out:
# GaussianNB()

# %%
## Predecimos los yd (etapa test)
ydPred =modeloNB.predict(XDArray)

# %% [markdown]
# ### 4.MATRIZ DE CONDUSION

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(YdArray, ydPred)
cm
# Out:
# array([[2539,  420],
#        [1041, 1842]])

# %% [markdown]
# ### 5.CALCULAR LAS MTRICAS DE EVALUACION DEL MODELO

# %%
## extraigo los valores de la matriz de confusion
VN = cm[0,0] ; FP = cm[0,1]; FN = cm[1,0]; VP = cm[1,1]

# %%
## exactitud
exactitud = (VP + VN)/ cm.sum()

## Error
error = (FP + FN)/ cm.sum()

## Precision
precision = VP/(FP+VP)

## Sensibilidad
sensibilidad = VP/(VP+FN)

## Especificidad
especificidad = VN/(FP+VN)

# %%
## Imprimo los mensajes
print(f'la exactitud del modelo es de {exactitud: .2%}')
print(f'la error del modelo es de {error: .2%}')
print(f'la precision del modelo es de {precision: .2%}')
print(f'la sensibilidad del modelo es de {sensibilidad: .2%}')
print(f'la especificidad del modelo es de {especificidad: .2%}')
# Out:
# la exactitud del modelo es de  74.99%
# la error del modelo es de  25.01%
# la precision del modelo es de  81.43%
# la sensibilidad del modelo es de  63.89%
# la especificidad del modelo es de  85.81%

# %% [markdown]
# ## 6.Generalizacion del modelo
#  (pronostico para solicitantes nuevos)

# %%
# filtro los que no tienen clasificacion (no tienen valor en la columna PreApr)
XDGener = solicitantes[solicitantes['PreApr'].isna()]

# %%
# Re-initialize XDGener from the original solicitantes DataFrame
XDGener = solicitantes[solicitantes['PreApr'].isna()]
## filtro las variables
XDGener = XDGener[['Edad','Hijos','Perscargo','Estrato','Ingresos','Egresos','Monto (EAD)','Plazo','Cuota (COP)']]

# %%
# convierto en arreglo
XDGenerArray = np.array(XDGener)

# %%
# GENERALIZO (genero las predicciones para los solicitantes faltantes)
ydGener = modeloNB.predict(XDGenerArray)

# %% [markdown]
# ### CONCLUSION
# # Bajo el nuevo escenario, el modelo Naive Bayes presenta un mejor desempeño general frente al escenario de la clase 2, evidenciado principalmente en la mejora de la precisión. Esto indica un clasificador más confiable y balanceado, aunque con una leve disminución en el recall, atribuida a un enfoque más conservador del modelo. En conjunto los resultados muestran un ajuste más adecuado al problema y una mejora en la calidad de las predicciones.
