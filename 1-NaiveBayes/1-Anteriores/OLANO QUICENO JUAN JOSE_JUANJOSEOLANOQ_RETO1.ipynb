# %% [markdown]
# # NAIVE BAYES

# %% [markdown]
# IMPORTAR DATOS

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
solicitantes = pd.read_excel('/content/drive/MyDrive/0. SolicitantesCrédito.xlsx')

# %%
solicitantes
# Out:
#       Unnamed: 0  Edad    Sexo Estado civil  Hijos  Perscargo  Estrato  \
# 0              1    38      NR       Casado      1          0        3
# 1              2    51      NR     Separado      6          1        4
# 2              3    37   Mujer       Casado      2          0        3
# 3              4    29      NR     Separado      1          0        2
# 4              5    42   Mujer       Casado      3          4        2
# ...          ...   ...     ...          ...    ...        ...      ...
# 8373        8374    31  Hombre      Soltero      2          0        5
# 8374        8375    38  Hombre     Separado      0          0        3
# 8375        8376    43   Mujer       Casado      1          2        2
# 8376        8377    37   Mujer       Casado      1          2        3
# 8377        8378    24      NR      Soltero      0          0        2
#
#      Nivel de estudios  Tipo de contrato  Ingresos  ...  Plazo    Cuota (COP)  \
# ...

# %% [markdown]
# PREPARAR VARIABLES

# %%
variables_independientes = [
    'Edad', 'Hijos', 'Perscargo', 'Estrato',
    'Ingresos', 'Egresos', 'Monto (EAD)', 'Plazo', 'Cuota (COP)'
]

print("\nVariables independientes seleccionadas:")
for i, var in enumerate(variables_independientes, 1):
    print(f"  {i}. {var}")

# Seleccionar variables independientes y dependiente
datos_modelo = solicitantes[variables_independientes + ['PreApr']]

print(f"\nRegistros antes de eliminar NaN: {len(datos_modelo)}")
datos_modelo = datos_modelo.dropna(subset=variables_independientes + ['PreApr'])
print(f"Registros después de eliminar NaN: {len(datos_modelo)}")

# Separar X e y
X_independientes = datos_modelo[variables_independientes]
y_dependiente = datos_modelo['PreApr']

print(f"\nDimensión X: {X_independientes.shape}")
print(f"Dimensión y: {y_dependiente.shape}")

# convertir a arrays

X_array = X_independientes.to_numpy()
y_array = y_dependiente.to_numpy()

print(f"\nX_array shape: {X_array.shape}")
print(f"y_array shape: {y_array.shape}")
# Out:
# Variables independientes seleccionadas:
#   1. Edad
#   2. Hijos
#   3. Perscargo
#   4. Estrato
#   5. Ingresos
#   6. Egresos
#   7. Monto (EAD)
#   8. Plazo
#   9. Cuota (COP)
#
# Registros antes de eliminar NaN: 8378
# Registros después de eliminar NaN: 5842
#
# Dimensión X: (5842, 9)
# Dimensión y: (5842,)
#
# X_array shape: (5842, 9)
# y_array shape: (5842,)

# %% [markdown]
# ENTRENAR MODELO GAUSSIAN NAIVE BAYES

# %%
modelo_gnb = GaussianNB()
modelo_gnb.fit(X_array, y_array)
# Out:
# GaussianNB()

# %% [markdown]
# PREDICCIONES

# %%
y_predicho = modelo_gnb.predict(X_array)

# %% [markdown]
# MATRIZ DE CONFUSIÓN

# %%
matriz_confusion = confusion_matrix(y_array, y_predicho)
print("\nMatriz de Confusión:")
print(matriz_confusion)

# Extraer valores
verdaderos_negativos = matriz_confusion[0, 0]
falsos_positivos = matriz_confusion[0, 1]
falsos_negativos = matriz_confusion[1, 0]
verdaderos_positivos = matriz_confusion[1, 1]

print("\nValores de la Matriz de Confusión:")
print(f"  • Verdaderos Negativos (VN): {verdaderos_negativos}")
print(f"  • Falsos Positivos (FP):     {falsos_positivos}")
print(f"  • Falsos Negativos (FN):     {falsos_negativos}")
print(f"  • Verdaderos Positivos (VP): {verdaderos_positivos}")
# Out:
# Matriz de Confusión:
# [[2539  420]
#  [1041 1842]]
#
# Valores de la Matriz de Confusión:
#   • Verdaderos Negativos (VN): 2539
#   • Falsos Positivos (FP):     420
#   • Falsos Negativos (FN):     1041
#   • Verdaderos Positivos (VP): 1842

# %% [markdown]
# METRICAS

# %%
exactitud = (verdaderos_positivos + verdaderos_negativos) / matriz_confusion.sum()
error = (falsos_positivos + falsos_negativos) / matriz_confusion.sum()
sensibilidad = verdaderos_positivos / (verdaderos_positivos + falsos_negativos)
precision = verdaderos_positivos / (verdaderos_positivos + falsos_positivos)
especificidad = verdaderos_negativos / (verdaderos_negativos + falsos_positivos)

print("\nMétricas del Modelo:")
print(f"  • Exactitud (Accuracy):   {exactitud:.2%}")
print(f"  • Error:                 {error:.2%}")
print(f"  • Sensibilidad:        {sensibilidad:.2%}")
print(f"  • Precisión:             {precision:.2%}")
print(f"  • Especificidad:        {especificidad:.2%}")
# Out:
# Métricas del Modelo:
#   • Exactitud (Accuracy):   74.99%
#   • Error:                 25.01%
#   • Sensibilidad:        63.89%
#   • Precisión:             81.43%
#   • Especificidad:        85.81%

# %% [markdown]
# El modelo Gaussian Naive Bayes, entrenado con el conjunto extendido de 9 variables, presenta un desempeño global aceptable, alcanzando una exactitud del 74.99%, lo que indica que aproximadamente 3 de cada 4 solicitantes son clasificados correctamente. Este resultado sugiere que el modelo captura patrones relevantes en los datos, la precisión del 81.43% y la especificidad del 85.81% muestran que el modelo es confiable al identificar correctamente a los solicitantes no preaprobados y al reducir aprobaciones incorrectas.
# Sin embargo, la sensibilidad del 63.89% muestra que el modelo no detecta a todos los solicitantes realmente preaprobables, presentando una tendencia conservadora en sus decisiones, esto es coherente con escenarios financieros donde el costo de aprobar erróneamente a un solicitante es mayor que el de rechazar a uno que sea potencialmente bueno.
